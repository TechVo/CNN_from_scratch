# %%
import numpy as np
import matplotlib.pyplot as plt
from  datasets import load_MURA

# %%
X_train, Y_train = load_MURA( data_type='valid', body_part="XR_WRIST")
# Out:
# /work/CNN_from_scratch/data/MURA-transformed_224px/valid/XR_WRIST/valid

# %%
#debug
print(type(X_train))
img = X_train[3]
print(np.mean(img))
print(img.shape)
preimg = img/255.
print(np.mean(preimg))
preimg = np.squeeze(preimg)
plt.imshow(preimg)
# Out:
# <class 'numpy.ndarray'>
# 25.147002551020407
# (224, 224, 1)
# 0.0986156962785114

# %%
Y_train[0]
# Out:
# 1

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=64d23a20-b5bc-41cc-930c-3bd7ede12b0c' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
